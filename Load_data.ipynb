# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import cv2

# %%
Directory = "F:\\dataset\\PetImages"
Categories = ['Cat','Dog']

# %%
training_data = []
IMG_SIZE = 80
def create_training_data():
    for category in Categories:
        folder = os.path.join(Directory,category)
        label = Categories.index(category)
        for img in os.listdir(folder):
            try:
                img_arr = cv2.imread(os.path.join(folder,img))
                new_arr = cv2.resize(img_arr, (IMG_SIZE,IMG_SIZE))
                training_data.append([new_arr, label])
            except Exception as e:
                pass
create_training_data()

# %%
len(training_data)
# Out:
# 24948

# %%
import random

random.shuffle(training_data)

# %%
X = []
y = []

for features,belong in training_data:
    X.append(features)
    y.append(belong)

# %%
X = np.array(X)
y = np.array(y)

# %%
X
# Out:
# array([[[[229, 221, 227],
#          [221, 220, 230],
#          [231, 223, 238],
#          ...,
#          [229, 226, 224],
#          [210, 198, 206],
#          [235, 228, 230]],
#
#         [[233, 224, 230],
#          [218, 217, 226],
#          [217, 209, 225],
#          ...,
#          [218, 214, 214],
#          [173, 161, 169],
#          [234, 227, 228]],
#
#         [[235, 226, 232],
#          [223, 222, 232],
#          [212, 203, 219],
#          ...,
#          [222, 217, 220],
#          [225, 213, 221],
#          [235, 228, 228]],
#
#         ...,
#
#         [[ 82, 121, 187],
#          [ 75, 109, 161],
#          [ 76, 113, 177],
#          ...,
#          [ 34,  53,  97],
#          [ 31,  50,  94],
#          [ 35,  54,  98]],
#
#         [[ 65,  96, 156],
#          [ 78, 103, 160],
#          [ 64, 104, 169],
#          ...,
#          [ 38,  66, 111],
#          [ 33,  59, 103],
#          [ 34,  59,  99]],
#
#         [[ 76, 106, 165],
#          [ 74,  99, 156],
#          [ 74, 115, 179],
#          ...,
#          [ 31,  60, 105],
#          [ 32,  58, 102],
#          [ 39,  64, 104]]],
#
#
#        [[[ 95, 181, 148],
#          [ 94, 179, 146],
#          [100, 182, 150],
#          ...,
#          [ 94, 177, 139],
#          [103, 182, 146],
#          [103, 176, 144]],
#
#         [[ 92, 177, 147],
#          [ 96, 181, 148],
#          [ 91, 174, 138],
#          ...,
#          [ 98, 182, 146],
#          [101, 180, 147],
#          [105, 178, 148]],
#
#         [[ 98, 186, 145],
#          [ 92, 176, 138],
#          [100, 182, 146],
#          ...,
#          [ 99, 170, 146],
#          [ 88, 153, 132],
#          [101, 158, 140]],
#
#         ...,
#
#         [[102, 121, 153],
#          [102, 121, 155],
#          [118, 137, 173],
#          ...,
#          [144, 121,  95],
#          [141, 118,  92],
#          [142, 119,  93]],
#
#         [[109, 130, 158],
#          [102, 123, 152],
#          [109, 129, 160],
#          ...,
#          [150, 127, 101],
#          [147, 124,  98],
#          [149, 126, 100]],
#
#         [[112, 134, 159],
#          [106, 127, 154],
#          [109, 129, 158],
#          ...,
#          [147, 125,  97],
#          [149, 126,  98],
#          [151, 126,  99]]],
#
#
#        [[[  2,   3,   7],
#          [  4,   5,  10],
#          [ 23,  26,  34],
#          ...,
#          [  1,   2,   3],
#          [  1,   3,   4],
#          [  8,   8,   8]],
#
#         [[  4,   3,   5],
#          [  3,   4,   9],
#          [ 28,  30,  38],
#          ...,
#          [  1,   3,   4],
#          [  5,   7,   8],
#          [ 13,  13,  13]],
#
#         [[  3,   1,   1],
#          [  3,   2,   6],
#          [ 35,  38,  45],
#          ...,
#          [  2,   4,   5],
#          [ 13,  15,  16],
#          [ 32,  32,  32]],
#
#         ...,
#
#         [[  2,   4,   4],
#          [  4,   6,   6],
#          [  1,   3,   3],
#          ...,
#          [  4,   4,   5],
#          [  3,   5,   7],
#          [  2,   4,   5]],
#
#         [[  2,   1,   5],
#          [  4,   3,   5],
#          [  1,   0,   2],
#          ...,
#          [ 12,  12,  12],
#          [  6,   6,   6],
#          [  4,   4,   4]],
#
#         [[  2,   1,   5],
#          [  4,   3,   5],
#          [  1,   0,   2],
#          ...,
#          [ 12,  12,  12],
#          [  8,   8,   8],
#          [  7,   7,   7]]],
#
#
#        ...,
#
#
#        [[[ 35,  37,  51],
#          [ 36,  37,  51],
#          [ 38,  39,  53],
#          ...,
#          [ 33,  26,  31],
#          [ 38,  31,  36],
#          [ 42,  33,  43]],
#
#         [[ 35,  37,  51],
#          [ 36,  37,  51],
#          [ 38,  39,  53],
#          ...,
#          [ 44,  37,  42],
#          [ 41,  34,  39],
#          [ 35,  27,  34]],
#
#         [[ 36,  37,  51],
#          [ 38,  39,  53],
#          [ 40,  41,  55],
#          ...,
#          [ 43,  36,  41],
#          [ 45,  38,  43],
#          [ 44,  37,  40]],
#
#         ...,
#
#         [[164, 165, 175],
#          [167, 168, 178],
#          [158, 159, 167],
#          ...,
#          [231, 241, 248],
#          [231, 239, 242],
#          [234, 238, 243]],
#
#         [[164, 165, 175],
#          [164, 165, 175],
#          [162, 164, 172],
#          ...,
#          [230, 238, 246],
#          [240, 246, 249],
#          [241, 244, 249]],
#
#         [[156, 157, 167],
#          [158, 159, 169],
#          [160, 162, 169],
#          ...,
#          [230, 234, 242],
#          [242, 245, 249],
#          [240, 243, 248]]],
#
#
#        [[[ 59,  73,  47],
#          [ 97, 114,  83],
#          [ 83,  97,  70],
#          ...,
#          [ 50, 111,  87],
#          [ 86, 140, 129],
#          [ 65, 122, 100]],
#
#         [[ 94, 116,  89],
#          [ 36,  52,  21],
#          [ 50,  62,  35],
#          ...,
#          [120, 172, 179],
#          [121, 165, 182],
#          [117, 165, 177]],
#
#         [[101, 124,  97],
#          [ 57,  72,  41],
#          [ 42,  53,  27],
#          ...,
#          [105, 158, 168],
#          [107, 154, 168],
#          [107, 156, 171]],
#
#         ...,
#
#         [[126, 145, 120],
#          [118, 124,  99],
#          [ 76,  90,  62],
#          ...,
#          [ 76,  94,  71],
#          [ 88, 104,  81],
#          [ 94, 110,  87]],
#
#         [[145, 159, 137],
#          [ 67,  76,  49],
#          [127, 140, 113],
#          ...,
#          [ 79,  95,  72],
#          [ 87, 103,  80],
#          [ 96, 110,  86]],
#
#         [[129, 145, 123],
#          [133, 143, 113],
#          [126, 140, 113],
#          ...,
#          [ 85, 101,  78],
#          [ 89, 105,  82],
#          [100, 113,  89]]],
#
#
#        [[[ 70,  55,  58],
#          [ 65,  53,  53],
#          [ 67,  57,  55],
#          ...,
#          [ 60,  55,  64],
#          [ 59,  54,  63],
#          [ 61,  56,  65]],
#
#         [[ 62,  50,  48],
#          [ 64,  54,  51],
#          [ 72,  65,  58],
#          ...,
#          [ 56,  46,  52],
#          [ 63,  53,  59],
#          [ 55,  47,  51]],
#
#         [[ 61,  59,  61],
#          [ 56,  56,  56],
#          [ 53,  57,  55],
#          ...,
#          [ 50,  47,  45],
#          [ 48,  45,  43],
#          [ 48,  44,  42]],
#
#         ...,
#
#         [[ 27,  18,  22],
#          [ 30,  22,  29],
#          [ 31,  25,  30],
#          ...,
#          [121, 157, 167],
#          [104, 145, 154],
#          [ 95, 137, 146]],
#
#         [[ 30,  19,  24],
#          [ 32,  23,  31],
#          [ 31,  24,  31],
#          ...,
#          [ 99, 137, 148],
#          [ 91, 125, 137],
#          [ 86, 118, 128]],
#
#         [[ 40,  27,  34],
#          [ 31,  20,  30],
#          [ 35,  27,  34],
#          ...,
#          [ 86, 123, 137],
#          [ 76, 116, 128],
#          [ 61, 100, 107]]]], dtype=uint8)

# %%
y
# Out:
# array([0, 1, 0, ..., 0, 1, 1])

# %%
import pickle

pickle.dump(X,open('X.pkl','wb'))
pickle.dump(y,open('y.pkl','wb'))
